# %%
import pandas as pd
import numpy as np 

df = pd.read_csv('I485_data_all.csv')
# df = df.drop(columns='Abbreviation')
df = df.replace("-", 0)
df = df.replace("d",np.NaN)
df = df.replace("D",np.NaN)
df['Received'].astype("float64")
# df.columns
# df["State"].value_counts()
# df.columns.values
# for col in df.columns.values:
#     # print(type(col))
#     # print(col)
#     print(df[col].value_counts())

df.info()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-109-597ba9ef2d9d> in <module>
#       7 df = df.replace("d",np.NaN)
#       8 df = df.replace("D",np.NaN)
# ----> 9 df['Received'].astype("float64")
#      10 # df.columns
#      11 # df["State"].value_counts()
#
# c:\Linux\python\uscis\venv\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5696         else:
#    5697             # else, only a single dtype is given
# -> 5698             new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors)
#    5699             return self._constructor(new_data).__finalize__(self)
#    5700
#
# c:\Linux\python\uscis\venv\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     580
#     581     def astype(self, dtype, copy: bool = False, errors: str = "raise"):
# ...
